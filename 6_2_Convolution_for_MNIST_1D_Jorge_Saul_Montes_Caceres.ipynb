# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-vkvnbsm4
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-vkvnbsm4
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=15957 sha256=630503dd17ebfe6b3517668e8e234d57c206598bf11b5fd70907d53b6a9f70b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wtu7or5n/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    nn.Conv1d(in_channels=1,  out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.907670, training error 74.97, validation loss 1.904938, validation error 74.50
# Epoch     1, training loss 1.527973, training error 60.15, validation loss 1.550332, validation error 60.90
# Epoch     2, training loss 1.341056, training error 54.08, validation loss 1.359285, validation error 56.40
# Epoch     3, training loss 1.238788, training error 50.70, validation loss 1.259107, validation error 53.30
# Epoch     4, training loss 1.217312, training error 51.05, validation loss 1.209047, validation error 50.20
# Epoch     5, training loss 1.033988, training error 41.33, validation loss 1.074681, validation error 44.70
# Epoch     6, training loss 1.000223, training error 39.53, validation loss 1.053239, validation error 42.50
# Epoch     7, training loss 0.929109, training error 37.47, validation loss 1.018878, validation error 42.80
# Epoch     8, training loss 0.874705, training error 34.95, validation loss 0.957032, validation error 38.60
# Epoch     9, training loss 0.780499, training error 30.88, validation loss 0.864079, validation error 34.00
# Epoch    10, training loss 0.692253, training error 27.12, validation loss 0.777127, validation error 30.40
# Epoch    11, training loss 0.630978, training error 24.85, validation loss 0.737007, validation error 30.00
# Epoch    12, training loss 0.646936, training error 25.85, validation loss 0.761270, validation error 31.80
# Epoch    13, training loss 0.596743, training error 21.65, validation loss 0.679845, validation error 26.70
# Epoch    14, training loss 0.535675, training error 19.93, validation loss 0.672338, validation error 26.00
# Epoch    15, training loss 0.469144, training error 17.82, validation loss 0.613126, validation error 23.20
# Epoch    16, training loss 0.419852, training error 15.30, validation loss 0.551077, validation error 20.40
# Epoch    17, training loss 0.408540, training error 14.47, validation loss 0.563360, validation error 19.50
# Epoch    18, training loss 0.343377, training error 12.20, validation loss 0.501896, validation error 17.40
# Epoch    19, training loss 0.303025, training error 11.00, validation loss 0.444124, validation error 15.50
# Epoch    20, training loss 0.279664, training error 9.90, validation loss 0.463262, validation error 16.10
# Epoch    21, training loss 0.223588, training error 7.82, validation loss 0.403257, validation error 14.10
# Epoch    22, training loss 0.206234, training error 6.82, validation loss 0.404115, validation error 12.00
# Epoch    23, training loss 0.197882, training error 6.72, validation loss 0.400995, validation error 12.30
# Epoch    24, training loss 0.186732, training error 6.57, validation loss 0.395712, validation error 12.60
# Epoch    25, training loss 0.176210, training error 6.05, validation loss 0.410623, validation error 12.40
# Epoch    26, training loss 0.174351, training error 6.25, validation loss 0.412234, validation error 12.60
# Epoch    27, training loss 0.161780, training error 5.57, validation loss 0.405384, validation error 12.10
# Epoch    28, training loss 0.149534, training error 5.10, validation loss 0.386151, validation error 11.50
# Epoch    29, training loss 0.154473, training error 5.32, validation loss 0.387056, validation error 11.70
# Epoch    30, training loss 0.133748, training error 4.53, validation loss 0.366957, validation error 12.00
# Epoch    31, training loss 0.134108, training error 4.32, validation loss 0.389499, validation error 11.80
# Epoch    32, training loss 0.142867, training error 4.88, validation loss 0.414700, validation error 12.30
# Epoch    33, training loss 0.129332, training error 4.55, validation loss 0.410296, validation error 11.20
# Epoch    34, training loss 0.122881, training error 4.28, validation loss 0.391728, validation error 11.10
# Epoch    35, training loss 0.113541, training error 3.97, validation loss 0.395262, validation error 11.50
# Epoch    36, training loss 0.112403, training error 3.82, validation loss 0.396154, validation error 11.50
# Epoch    37, training loss 0.110470, training error 3.62, validation loss 0.411151, validation error 11.80
# Epoch    38, training loss 0.103426, training error 3.50, validation loss 0.414620, validation error 11.60
# Epoch    39, training loss 0.109834, training error 3.72, validation loss 0.403835, validation error 11.90
# Epoch    40, training loss 0.083642, training error 2.55, validation loss 0.395798, validation error 11.60
# Epoch    41, training loss 0.079036, training error 2.53, validation loss 0.408875, validation error 11.40
# Epoch    42, training loss 0.082801, training error 2.50, validation loss 0.407316, validation error 10.80
# Epoch    43, training loss 0.073906, training error 2.32, validation loss 0.416736, validation error 11.30
# Epoch    44, training loss 0.070695, training error 1.78, validation loss 0.401267, validation error 11.50
# Epoch    45, training loss 0.073048, training error 2.22, validation loss 0.417734, validation error 11.00
# Epoch    46, training loss 0.067875, training error 1.88, validation loss 0.414881, validation error 11.30
# Epoch    47, training loss 0.070696, training error 2.25, validation loss 0.420934, validation error 11.00
# Epoch    48, training loss 0.067952, training error 1.95, validation loss 0.425503, validation error 11.30
# Epoch    49, training loss 0.063389, training error 1.70, validation loss 0.425079, validation error 11.20
# Epoch    50, training loss 0.065715, training error 1.78, validation loss 0.428531, validation error 11.40
# Epoch    51, training loss 0.066836, training error 1.85, validation loss 0.447015, validation error 11.40
# Epoch    52, training loss 0.063784, training error 1.72, validation loss 0.440758, validation error 11.40
# Epoch    53, training loss 0.062758, training error 1.57, validation loss 0.446366, validation error 11.30
# Epoch    54, training loss 0.062319, training error 1.70, validation loss 0.434512, validation error 11.10
# Epoch    55, training loss 0.059966, training error 1.57, validation loss 0.448688, validation error 11.70
# Epoch    56, training loss 0.060808, training error 1.70, validation loss 0.463298, validation error 11.20
# Epoch    57, training loss 0.056757, training error 1.43, validation loss 0.439614, validation error 11.20
# Epoch    58, training loss 0.054321, training error 1.28, validation loss 0.459416, validation error 11.60
# Epoch    59, training loss 0.052789, training error 1.18, validation loss 0.439938, validation error 10.80
# Epoch    60, training loss 0.049240, training error 1.07, validation loss 0.451195, validation error 11.30
# Epoch    61, training loss 0.048983, training error 1.10, validation loss 0.456930, validation error 11.30
# Epoch    62, training loss 0.048191, training error 1.07, validation loss 0.458818, validation error 11.50
# Epoch    63, training loss 0.046604, training error 1.00, validation loss 0.456668, validation error 11.70
# Epoch    64, training loss 0.046120, training error 0.90, validation loss 0.458814, validation error 11.30
# Epoch    65, training loss 0.046525, training error 0.90, validation loss 0.462491, validation error 11.80
# Epoch    66, training loss 0.045067, training error 1.03, validation loss 0.460314, validation error 10.90
# Epoch    67, training loss 0.044874, training error 0.97, validation loss 0.459981, validation error 11.20
# Epoch    68, training loss 0.044144, training error 0.95, validation loss 0.460674, validation error 11.60
# Epoch    69, training loss 0.043685, training error 0.95, validation loss 0.462875, validation error 11.30
# Epoch    70, training loss 0.044846, training error 1.07, validation loss 0.472680, validation error 11.50
# Epoch    71, training loss 0.045091, training error 0.93, validation loss 0.469627, validation error 11.30
# Epoch    72, training loss 0.042701, training error 0.95, validation loss 0.469404, validation error 11.00
# Epoch    73, training loss 0.042469, training error 0.75, validation loss 0.459987, validation error 11.20
# Epoch    74, training loss 0.041954, training error 0.85, validation loss 0.475983, validation error 11.20
# Epoch    75, training loss 0.041457, training error 0.80, validation loss 0.470064, validation error 11.50
# Epoch    76, training loss 0.041649, training error 0.88, validation loss 0.474119, validation error 11.00
# Epoch    77, training loss 0.041327, training error 0.72, validation loss 0.471322, validation error 11.20
# Epoch    78, training loss 0.039973, training error 0.80, validation loss 0.477413, validation error 11.20
# Epoch    79, training loss 0.041114, training error 0.88, validation loss 0.479462, validation error 11.20
# Epoch    80, training loss 0.038830, training error 0.70, validation loss 0.476713, validation error 11.30
# Epoch    81, training loss 0.038375, training error 0.65, validation loss 0.475532, validation error 11.40
# Epoch    82, training loss 0.038250, training error 0.62, validation loss 0.479642, validation error 11.60
# Epoch    83, training loss 0.038242, training error 0.70, validation loss 0.479897, validation error 11.70
# Epoch    84, training loss 0.037941, training error 0.57, validation loss 0.475949, validation error 11.20
# Epoch    85, training loss 0.037849, training error 0.65, validation loss 0.480522, validation error 11.40
# Epoch    86, training loss 0.038026, training error 0.72, validation loss 0.484258, validation error 11.50
# Epoch    87, training loss 0.037197, training error 0.62, validation loss 0.478964, validation error 11.30
# Epoch    88, training loss 0.037685, training error 0.57, validation loss 0.481098, validation error 11.20
# Epoch    89, training loss 0.037116, training error 0.68, validation loss 0.485538, validation error 11.50
# Epoch    90, training loss 0.036880, training error 0.57, validation loss 0.484907, validation error 11.50
# Epoch    91, training loss 0.036648, training error 0.55, validation loss 0.481337, validation error 11.40
# Epoch    92, training loss 0.037171, training error 0.62, validation loss 0.478710, validation error 11.30
# Epoch    93, training loss 0.036549, training error 0.60, validation loss 0.484152, validation error 11.20
# Epoch    94, training loss 0.037250, training error 0.70, validation loss 0.490409, validation error 11.60
# Epoch    95, training loss 0.036096, training error 0.65, validation loss 0.488398, validation error 11.50
# Epoch    96, training loss 0.036110, training error 0.53, validation loss 0.486259, validation error 11.00
# Epoch    97, training loss 0.035478, training error 0.57, validation loss 0.486686, validation error 11.20
# Epoch    98, training loss 0.036320, training error 0.60, validation loss 0.490791, validation error 11.40
# Epoch    99, training loss 0.035713, training error 0.60, validation loss 0.490227, validation error 11.30
